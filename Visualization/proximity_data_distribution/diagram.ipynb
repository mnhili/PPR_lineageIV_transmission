# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# Load the data
file_path = r"D:\CIRAD_2024\pprv-lineage4-study\notebooks\proximity_data_distribution\stratified_proximity_data.csv"
df = pd.read_csv(file_path)

# %%
df
# Out:
#     experiment  duration  seeder  Cap2  time_between_0.05_and_0.5m  \
# 0            1         1     436   100                    2.783333
# 1            1         1     436   116                    4.500000
# 2            1         1     436   255                    6.200000
# 3            1         1     436   449                   17.016667
# 4            1         1     436  3008                    0.183333
# 5            1         1     436  3310                    4.116667
# 6            1         6     436   100                    0.566667
# 7            1         6     436   116                   15.533333
# 8            1         6     436   255                    0.733333
# 9            1         6     436   449                    4.066667
# 10           1         6     436  3008                    2.350000
# 11           1         6     436  3310                    3.766667
# 12           1        24     436   100                    2.383333
# 13           1        24     436   116                    0.800000
# 14           1        24     436   255                   14.433333
# 15           1        24     436   449                    6.333333
# 16           1        24     436  3008                   27.833333
# 17           1        24     436  3310                   12.816667
# 18           2        24     218   100                    8.916667
# 19           2        24     218   116                    1.833333
# 20           2        24     218   255                    0.133333
# 21           2        24     218   376                    0.750000
# 22           2        24     218   436                    9.666667
# 23           2        24     218   742                    1.716667
# 24           2        44     218   100                    2.666667
# 25           2        44     218   116                   11.633333
# 26           2        44     218   255                    2.466667
# 27           2        44     218   376                    9.083333
# 28           2        44     218   436                    5.733333
# 29           2        44     218   742                   15.166667
# 30           3        24    3837   100                    2.133333
# 31           3        24    3837   116                    0.733333
# 32           3        24    3837   218                    1.533333
# 33           3        24    3837   255                    2.566667
# 34           3        24    3837   436                    2.666667
# 35           4        24    3837   255                    5.383333
# 36           4        24    3837   376                    0.600000
# 37           4        24    3837   436                    0.150000
# 38           4        24    3837   742                    0.350000
# 39           4        24    3837  2372                    1.350000
# 40           4        24    3837  3008                    0.083333
# 41           4        48    3837   255                    6.150000
# 42           4        48    3837   376                    2.200000
# 43           4        48    3837   436                  158.266667
# 44           4        48    3837   742                   10.733333
# 45           4        48    3837  3008                   32.600000
# 46           5        24    3837   255                    2.133333
# 47           5        24    3837   376                    5.166667
# 48           5        24    3837   436                    3.800000
# 49           5        24    3837   742                   26.483333
# 50           5        24    3837  2372                    0.383333
# 51           5        24    3837  3008                    5.183333
# 52           5        48    3837   218                    4.450000
# 53           5        48    3837   376                  138.933333
# 54           5        48    3837   436                    0.983333
# 55           5        48    3837   742                    0.733333
# 56           5        48    3837  2372                    3.000000
# 57           5        48    3837  3008                    1.016667
#
#     time_between_0.5_and_1m  time_between_1_and_2m  time_above_2m  infected
# 0                 10.600000              23.483333      25.850000         0
# 1                 20.983333              23.216667      13.916667         0
# 2                 20.900000              27.200000       8.416667         0
# 3                 20.733333              15.933333       9.050000         0
# 4                  1.033333               9.700000      51.816667         0
# 5                 18.683333              25.383333      14.300000         0
# 6                 13.700000             143.916667     211.983333         0
# 7                 51.600000             106.383333     196.683333         0
# 8                 26.000000             190.916667     152.233333         0
# 9                 41.483333             114.516667     210.050000         0
# 10                15.700000             105.733333     246.366667         0
# 11                30.166667             116.266667     220.633333         0
# 12                54.233333             194.433333    1217.750000         0
# 13                 9.300000              32.866667    1425.516667         0
# 14                86.716667             386.983333     981.316667         0
# 15               127.650000             299.900000    1033.683333         0
# 16               205.400000             476.633333     758.850000         0
# 17               115.600000             399.716667     940.733333         0
# 18                40.500000              58.550000      86.600000         0
# 19                19.966667             103.200000      69.283333         0
# 20                 4.950000              23.900000     164.800000         0
# 21                 3.800000              42.200000     147.383333         0
# 22                84.400000              68.400000      31.800000         0
# 23                11.633333              75.983333     104.933333         1
# 24                68.400000             511.033333    2092.950000         0
# 25               135.616667             416.583333    2110.900000         0
# 26                75.716667             426.350000    2169.183333         1
# 27               110.850000             310.183333    2245.450000         1
# 28               103.800000             629.100000    1936.450000         1
# 29               198.233333             316.733333    2144.533333         1
# 30                13.366667             159.833333    1283.033333         0
# 31                 9.233333             147.700000    1300.200000         1
# 32                40.616667             130.066667    1286.000000         1
# 33                99.766667             187.066667    1167.783333         1
# 34                41.850000             177.850000    1235.016667         0
# 35                45.266667             150.233333    1257.333333         0
# 36                 7.316667              48.683333    1401.866667         0
# 37                 1.800000              35.500000    1421.000000         0
# 38                 3.183333              54.033333    1400.783333         0
# 39                 3.333333              27.750000    1181.733333         0
# 40                 1.933333              99.316667    1357.116667         0
# 41                58.316667             161.483333    2691.450000         1
# 42                14.600000             221.866667    2678.933333         1
# 43               378.300000             394.916667    1985.616667         1
# 44                73.066667             130.633333    2703.050000         1
# 45                88.533333             250.400000    2545.983333         0
# 46                49.466667             360.466667    1029.966667         1
# 47                68.816667             403.550000     966.350000         0
# 48                34.616667             507.116667     897.616667         0
# 49               184.583333             462.700000     769.383333         0
# 50                21.883333             321.433333    1099.683333         0
# 51                53.866667             256.333333    1127.800000         0
# 52                73.883333             471.100000    2143.383333         1
# 53               485.050000             576.416667    1697.216667         0
# 54                 7.800000             153.550000    2734.583333         1
# 55                15.316667             219.166667    2661.816667         0
# 56                21.250000             197.566667    2675.850000         0
# 57                26.233333             333.583333    2536.800000         1

# %%
# Calculate the sum of time values for each row
row_sums = df[['time_between_0.05_and_0.5m', 'time_between_0.5_and_1m', 'time_between_1_and_2m', 'time_above_2m']].sum(axis=1)

# Create a new DataFrame with normalized time values
normalized_df = df[['experiment', 'duration', 'seeder', 'Cap2', 'infected']].copy()
normalized_df['time_between_0.05_and_0.5m'] = df['time_between_0.05_and_0.5m'] / row_sums * 100
normalized_df['time_between_0.5_and_1m'] = df['time_between_0.5_and_1m'] / row_sums * 100
normalized_df['time_between_1_and_2m'] = df['time_between_1_and_2m'] / row_sums * 100
normalized_df['time_above_2m'] = df['time_above_2m'] / row_sums * 100

normalized_df
# Out:
#     experiment  duration  seeder  Cap2  infected  time_between_0.05_and_0.5m  \
# 0            1         1     436   100         0                    4.437948
# 12                 3.692357              13.237564      82.907816
# 13                 0.633306               2.238137      97.074079
# 14                 5.901301              26.335250      66.781222
# 15                 8.698072              20.435188      70.435187
# 16                13.984998              32.452368      51.667556
# 17                 7.870013              27.212590      64.044842
# 18                20.815487              30.092513      44.509166
# 19                10.277087              53.118298      35.660976
# 20                 2.554399              12.333362      85.043433
# 21                 1.957418              21.737637      75.918613
# 22                43.445436              35.209334      16.369252
# 23                 5.988332              39.112903      54.015100
# 24                 2.556962              19.103693      78.239659
# 25                 5.070287              15.574761      78.920017
# 26                 2.831888              15.945968      81.129888
# 27                 4.143048              11.593183      83.924278
# 28                 3.880253              23.517024      72.388399
# 29                 7.411515              11.841974      80.179462
# 30                 0.916550              10.959749      87.977418
# 31                 0.633346              10.131242      89.185111
# 32                 2.785366               8.919571      88.189912
# 33                 6.846542              12.837552      80.139767
# 34                 2.871585              12.203378      84.742061
# 35                 3.104248              10.302538      86.224041
# 36                 0.501668               3.337981      96.119212
# 37                 0.123419               2.434091      97.432205
# 38                 0.218283               3.705101      96.052617
# 39                 0.274537               2.285518      97.328758
# 40                 0.132561               6.809741      93.051984
# 41                 1.998926               5.535180      92.255090
# 42                 0.500411               7.604424      91.819761
# 43                12.968359              13.537989      68.068173
# 44                 2.504442               4.477603      92.650058
# 45                 3.034544               8.582642      87.265426
# 46                 3.430341              24.997111      71.424609
# 47                 4.766082              27.948934      66.927152
# 48                 2.398688              35.139567      62.198432
# 49                12.790308              32.061809      53.312776
# 50                 1.516114              22.269436      76.187892
# 51                 3.732490              17.761661      78.146690
# 52                 2.743719              17.494693      79.596333
# 53                16.739619              19.892785      58.572850
# 54                 0.269252               5.300463      94.396341
# 55                 0.528702               7.565210      91.880775
# 56                 0.733349               6.818130      92.344990
# 57                 0.905337              11.512269      87.547309

# %%
infected_indices = np.where(df['infected'] == 1)[0].tolist()
infected_indices
# Out:
# [23, 26, 27, 28, 29, 31, 32, 33, 41, 42, 43, 44, 46, 52, 54, 57]

# %%
# Define the colors for each distance range
colors = ['blue', 'green', 'orange', 'red']

# Create a figure and axis
fig, ax = plt.subplots(figsize=(15, 40))

# Plot the stacked horizontal bars
ax.barh(normalized_df.index, normalized_df['time_between_0.05_and_0.5m'], color=colors[0], label='0.05 - 0.5 m')
ax.barh(normalized_df.index, normalized_df['time_between_0.5_and_1m'], left=normalized_df['time_between_0.05_and_0.5m'], color=colors[1], label='0.5 - 1 m')
ax.barh(normalized_df.index, normalized_df['time_between_1_and_2m'], left=normalized_df['time_between_0.05_and_0.5m'] + normalized_df['time_between_0.5_and_1m'], color=colors[2], label='1 - 2 m')
ax.barh(normalized_df.index, normalized_df['time_above_2m'], left=normalized_df['time_between_0.05_and_0.5m'] + normalized_df['time_between_0.5_and_1m'] + normalized_df['time_between_1_and_2m'], color=colors[3], label='> 2 m')

# Add labels for distance range
ax.set_yticks(normalized_df.index)
ax.set_yticklabels(normalized_df['experiment'])

# Add a legend
ax.legend()

# Set the x-axis label
ax.set_xlabel('Percentage of Time')

# Show the plot

# Concatenate the labels for y-axis ticks
tick_labels = normalized_df['experiment'].astype(str) + ', ' + normalized_df['duration'].astype(str) + ', ' + normalized_df['Cap2'].astype(str)

# Set the tick labels
ax.set_yticklabels(tick_labels)
# Sort the bars by y-axis ticks
ax.invert_yaxis()

# Set the x-axis tick frequency to 10%
ax.set_xticks(np.arange(0, 101, 10))

# Fix to show "infected" text
for i, (infected, total_width) in enumerate(zip(normalized_df['infected'], normalized_df['time_between_0.05_and_0.5m'] + normalized_df['time_between_0.5_and_1m'] + normalized_df['time_between_1_and_2m'] + normalized_df['time_above_2m'])):
    if infected:
        ax.text(total_width/2, i, 'infected', va='center', ha='center', color='black', fontweight='bold')

# Add % symbol to x-ticks
ax.set_xticklabels([f'{x}%' for x in ax.get_xticks()])


plt.title('Stacked Bar Chart of Time Spent in Different Distance Ranges')
# Out:
# Text(0.5, 1.0, 'Stacked Bar Chart of Time Spent in Different Distance Ranges')

# %%
fig.savefig('figure.pdf', dpi=300, bbox_inches='tight', format='pdf')

# %%
# Define the colors for each distance range
colors = ['blue', 'green', 'orange', 'red']

# Create a figure and axis
fig, ax = plt.subplots(figsize=(15, 50))

# Plot the stacked horizontal bars
ax.barh(df.index, df['time_between_0.05_and_0.5m'], color=colors[0], label='0.05 - 0.5 m')
ax.barh(df.index, df['time_between_0.5_and_1m'], left=df['time_between_0.05_and_0.5m'], color=colors[1], label='0.5 - 1 m')
ax.barh(df.index, df['time_between_1_and_2m'], left=df['time_between_0.05_and_0.5m'] + df['time_between_0.5_and_1m'], color=colors[2], label='1 - 2 m')
ax.barh(df.index, df['time_above_2m'], left=df['time_between_0.05_and_0.5m'] + df['time_between_0.5_and_1m'] + df['time_between_1_and_2m'], color=colors[3], label='> 2 m')

# Add labels for distance range
ax.set_yticks(df.index)
ax.set_yticklabels(df['experiment'])

# Add a legend
ax.legend()

# Set the x-axis label
ax.set_xlabel('Time')

# Show the plot

# Concatenate the labels for y-axis ticks
tick_labels = df['experiment'].astype(str) + ', ' + df['duration'].astype(str) + ', ' + df['Cap2'].astype(str)

# Set the tick labels
ax.set_yticklabels(tick_labels)
# Sort the bars by y-axis ticks
ax.invert_yaxis()

# Set the x-axis tick frequency to 10%
# ax.set_xticks(np.arange(0, 50, 1))


for i, (infected, total_width) in enumerate(zip(df['infected'], df['time_between_0.05_and_0.5m'] + df['time_between_0.5_and_1m'] + df['time_between_1_and_2m'] + df['time_above_2m'])):
    if infected:
        ax.text(total_width/2, i, 'infected', va='center', ha='center', color='black', fontweight='bold')


plt.title('Stacked Bar Chart of Time Spent in Different Distance Ranges')
# Out:
# Text(0.5, 1.0, 'Stacked Bar Chart of Time Spent in Different Distance Ranges')
